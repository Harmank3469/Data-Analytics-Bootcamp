# %%
import sqlite3
conn=sqlite3.connect('bill.db')
cur=conn.cursor()
cur.execute('''
create table if not EXISTS Bill (
    Bill_No integer primary key autoincrement,
    Biller_Name text,
    Product_Name text,
    Contact_No integer,
    Amount real
)
''')
conn.commit()

# %%
def create_bill(Biller_Name,Product_Name,Contact_No,Amount):
    cur.execute("Insert into bill(Biller_Name,Product_Name,Contact_No,Amount) values(?,?,?,?)",(Biller_Name,Product_Name,Contact_No,Amount))
    conn.commit
    print("BILL CREATED SUCCESSFULLY")

# %%
def update_bill(Bill_No,New_Biller_Name,New_Product_Name,New_Contact_No,New_Amount):
    cur.execute("Update bill set Biller_Name=?,Product_Name=?,Contact_No=?,Amount=? where Bill_No=?",(New_Biller_Name,New_Product_Name,New_Contact_No,New_Amount,Bill_No))
    conn.commit()
    print("BILL UPDATED SUCCESSFULLY")

# %%
def fetch_bill():
    cur.execute("Select * from bill")
    rows=cur.fetchall()
    for row in rows:
        print(row)

# %%
def delete_bill(Bill_No):
    cur.execute("Delete from bill where Bill_No=?",(Bill_No,))
    conn.commit
    print("DELETED SUCCESSFULLY")

# %%
def bill_menu():
    print("***BILL MENU***")
    while True:
        print("\n--- Menu ---")
        print("1. Create Bill")
        print("2. Update Bill")
        print("3. View Bill")
        print("4. Delete Bill")
        print("5. Exit")
        choice=input("Enter your choice: ")
        if choice=='1':
            Biller_Name=input("Enter Biller Name:")
            Product_Name=input("Enter Product Name:")
            Contact_No=input("Enter Contact:")
            Amount=float(input("Enter Amount:"))
            create_bill(Biller_Name,Product_Name,Contact_No,Amount)
        elif choice=='2':
            Bill_No=input("Enter Bill Number:")
            New_Biller_Name=input("Enter new Biller Name:")
            New_Product_Name=input("Enter new Product Name:")
            New_Contact_No=input("Enter new Contact:")
            New_Amount=float(input("Enter new Amount:"))
            update_bill(Bill_No,New_Biller_Name,New_Product_Name,New_Contact_No,New_Amount)
        elif choice == '3':
            fetch_bill()
        elif choice == '4':
            Bill_No=int(input("Enter Bill No to Delete"))
            delete_bill(Bill_No)
        elif choice == '5':
            print(" Thank you for using the Billing System. Bye!")
            break
        else:
            print("Invalid choice.")
    conn.close()
    print("DATABASE CONNECTION CLOSED")
bill_menu()
# Out:
# ***BILL MENU***
#
# --- Menu ---
# 1. Create Bill
# 2. Update Bill
# 3. View Bill
# 4. Delete Bill
# 5. Exit
# Enter your choice:  3
# --- Menu ---
# 1. Create Bill
# 2. Update Bill
# 3. View Bill
# 4. Delete Bill
# 5. Exit
# Enter your choice:  1
# Enter Biller Name: harman
# Enter Product Name: ice creame
# Enter Contact: 98711234567
# Enter Amount: 100
# BILL CREATED SUCCESSFULLY
#
# --- Menu ---
# 1. Create Bill
# 2. Update Bill
# 3. View Bill
# 4. Delete Bill
# 5. Exit
# Enter your choice:  1
# Enter Biller Name: manhar
# Enter Product Name: chocolate
# Enter Contact: 8976534012
# Enter Amount: 150
# BILL CREATED SUCCESSFULLY
#
# --- Menu ---
# 1. Create Bill
# 2. Update Bill
# 3. View Bill
# 4. Delete Bill
# 5. Exit
# Enter your choice:  3
# (1, 'harman', 'ice creame', 98711234567, 100.0)
# (2, 'manhar', 'chocolate', 8976534012, 150.0)
#
# --- Menu ---
# 1. Create Bill
# 2. Update Bill
# 3. View Bill
# 4. Delete Bill
# 5. Exit
# Enter your choice:  5
#  Thank you for using the Billing System. Bye!
# DATABASE CONNECTION CLOSED
